# %%
import pandas as pd
import xlrd

# %%
file = pd.read_csv("resorts.csv")
file
# Out:
#     Region        Country  SiteID  \
# 0   Africa  South Africa     7175
# 1   Africa  South Africa     7107
# 2   Africa  South Africa     7149
# 3   Africa  South Africa    44672
# 4   Africa  South Africa     7089
# ..     ...            ...     ...
# 94  Africa  South Africa     7081
# 95  Africa  South Africa     7159
# 96  Africa  South Africa     7168
# 97  Africa  South Africa     7079
# 98  Africa  South Africa     7148
#
#                                         National Name  \
# 0                 Agulhas Plain - Heuningnes Estuary
# 1                                            Alexpan
# 2     Algoa Bay Islands: Addo Elephant National Park
# 3                         Amatole - Katberg Mountain
# 4            Amersfoort - Bethal - Carolina District
# ..                                                ...
# 94                                  Waterberg System
# 95  West Coast National Park and Saldanha Bay isla...
# 96             Wilderness - Sedgefield Lakes Complex
# ...

# %%
# coordinates_file = file.iloc[0::, 7:9]
longitude = list(file["Longitude"])
latitude = list(file["Latitude"])

# %%
coordinates= [[latitude[i], longitude[i]] for i in range(len(latitude))]

# %%
name = list(file["International Name"])
